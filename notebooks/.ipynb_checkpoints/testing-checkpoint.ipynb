# %%
"""overfiting issue exist here"""
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# Load the test data
X_test = pd.read_csv('./../data/X_test.csv')
y_test = pd.read_csv('./../data/y_test.csv').squeeze()  # Ensure y_test is a Series, not a DataFrame

# Load the training data for evaluation purposes
X_train = pd.read_csv('./../data/X_train.csv')
y_train = pd.read_csv('./../data/y_train.csv').squeeze()  # Ensure y_train is a Series, not a DataFrame

# Load the trained model
model_path = './../models/random_forest.pkl'  # Path to the saved model
with open(model_path, 'rb') as file:
    model = pickle.load(file)

# Function to evaluate the model
def evaluate_model(model, X_train, y_train, X_test, y_test):
    # Training data evaluation
    y_train_pred = model.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_confusion_mat = confusion_matrix(y_train, y_train_pred)
    
    # Testing data evaluation
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    test_confusion_mat = confusion_matrix(y_test, y_pred)
    
    return accuracy, report, test_confusion_mat, train_accuracy, train_confusion_mat

# Evaluate the Random Forest model
results = {}
model_name = 'Random Forest'
accuracy, report, test_confusion_mat, train_accuracy, train_confusion_mat = evaluate_model(model, X_train, y_train, X_test, y_test)
results[model_name] = {
    'accuracy': accuracy,
    'training set accuracy': train_accuracy,
    'report': report,
    'test_confusion_matrix': test_confusion_mat,
    'train_confusion_matrix': train_confusion_mat
}

# Print the evaluation results
for model_name, result in results.items():
    print(f"Model: {model_name}")
    print(f"Testing data Accuracy: {result['accuracy']:.4f}")
    print(f"Training data Accuracy: {result['training set accuracy']:.4f}")
    print("Classification Report:")
    print(result['report'])
    print("Test Confusion Matrix:")
    print(result['test_confusion_matrix'])
    print("Train Confusion Matrix:")
    print(result['train_confusion_matrix'])
    print("\n")

# Visualize confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Test Confusion Matrix
sns.heatmap(results['Random Forest']['test_confusion_matrix'], annot=True, fmt="d", cmap="Blues", ax=axes[0])
axes[0].set_title(f'Confusion Matrix: Random Forest (Test Data)')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# Train Confusion Matrix
sns.heatmap(results['Random Forest']['train_confusion_matrix'], annot=True, fmt="d", cmap="Blues", ax=axes[1])
axes[1].set_title(f'Confusion Matrix: Random Forest (Train Data)')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()
# Out:
# Model: Random Forest
# Testing data Accuracy: 0.9096
# Training data Accuracy: 0.9998
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.94      0.91     17496
#          1.0       0.94      0.96      0.95     17695
#          2.0       0.91      0.83      0.87     17540
#
#     accuracy                           0.91     52731
#    macro avg       0.91      0.91      0.91     52731
# weighted avg       0.91      0.91      0.91     52731
#
# Test Confusion Matrix:
# [[16489    14   993]
#  [  378 16943   374]
#  [ 2031   976 14533]]
# Train Confusion Matrix:
# [[40919     0     5]
#  [    6 41198     1]
#  [   14     0 40896]]
